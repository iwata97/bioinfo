# %% [markdown]
# # 🧬 シングルセル解析
# このノートブックでは、`scanpy` を用いて、ヒト末梢血単核細胞（PBMC）から得られた scRNA-seq データ（PBMC3K）を処理し、クラスタリングと PanglaoDB マーカーによる細胞型推定を行う。
#
# ---
# ## 📚 手順概要
#
# 1. データ読み込み（PBMC3k）
# 2. 品質管理（QC）と前処理
# 3. 正規化とスケーリング
# 4. 次元削減とクラスタリング
# 5. クラスタごとのマーカー遺伝子抽出
# 6. PanglaoDBのマーカー遺伝子を読み込み
# 7. クラスタごとに細胞型を推定（PanglaoDBと照合）
# 8. 細胞型ラベルを各細胞に割り当てる
# 9. 細胞型ラベルでUMAPを描画

# %% [markdown]
# ## 🚀 ライブラリのインストール（初回のみ）

# %%
# !pip install scanpy
# !pip install igraph
# !pip install leidenalg
# Out:
# Collecting scanpy
#   Downloading scanpy-1.10.3-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 6.2 MB/s eta 0:00:01
# Collecting get-annotations
#   Downloading get_annotations-0.1.2-py3-none-any.whl (4.5 kB)
# Collecting session-info
#   Downloading session_info-1.0.1-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: h5py>=3.1 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from scanpy) (3.2.1)
# Collecting umap-learn!=0.5.0,>=0.5
#   Downloading umap_learn-0.5.9.post2-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 18.1 MB/s eta 0:00:01
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 16.2 MB/s eta 0:00:01
# Collecting networkx>=2.7
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 28.4 MB/s eta 0:00:01
# Collecting packaging>=21.3
#   Downloading packaging-25.0-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 17.7 MB/s eta 0:00:01
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Collecting seaborn>=0.13
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 27.8 MB/s eta 0:00:01
# Collecting anndata>=0.8
#   Downloading anndata-0.10.9-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 32.5 MB/s eta 0:00:01
# Collecting scipy>=1.8
#   Downloading scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
#      |████████████████████████████████| 39.4 MB 32.3 MB/s eta 0:00:01     |████████▍                       | 10.3 MB 20.7 MB/s eta 0:00:02
# Collecting numpy>=1.23
#   Downloading numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
#      |████████████████████████████████| 21.2 MB 20.9 MB/s eta 0:00:01
# Collecting matplotlib>=3.6
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 33.3 MB/s eta 0:00:01
# Collecting numba>=0.56
#   Downloading numba-0.60.0-cp39-cp39-macosx_10_9_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 25.6 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from scanpy) (4.62.3)
# Requirement already satisfied: scikit-learn>=0.24 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from scanpy) (0.24.2)
# Collecting statsmodels>=0.13
#   Downloading statsmodels-0.14.5-cp39-cp39-macosx_10_9_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 27.2 MB/s eta 0:00:01
# Collecting pandas>=1.5
#   Downloading pandas-2.3.1-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 21.9 MB/s eta 0:00:01
# Requirement already satisfied: patsy in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from scanpy) (0.5.2)
# Requirement already satisfied: joblib in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from scanpy) (1.1.0)
# Collecting legacy-api-wrap>=1.4
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Collecting array-api-compat!=1.5,>1.4
#   Downloading array_api_compat-1.11.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 9.6 MB/s  eta 0:00:01
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: cycler>=0.10 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
#      |████████████████████████████████| 265 kB 31.5 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow>=8 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.6->scanpy) (3.0.4)
# Requirement already satisfied: six in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.6->scanpy) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->scanpy) (3.6.0)
# Collecting llvmlite<0.44,>=0.43.0dev0
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_10_9_x86_64.whl (31.1 MB)
#      |████████████████████████████████| 31.1 MB 24.3 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 23.1 MB/s eta 0:00:01
# Requirement already satisfied: pytz>=2020.1 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.5->scanpy) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24->scanpy) (2.2.0)
# Collecting patsy
#   Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Collecting scikit-learn>=0.24
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
#      |████████████████████████████████| 12.1 MB 18.6 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#      |████████████████████████████████| 307 kB 23.4 MB/s eta 0:00:01
# Collecting typing-extensions>=4.6.0
#   Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 12.7 MB/s eta 0:00:01
# Collecting stdlib_list
#   Downloading stdlib_list-0.11.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 7.9 MB/s  eta 0:00:01
# Installing collected packages: numpy, threadpoolctl, scipy, llvmlite, joblib, tzdata, typing-extensions, scikit-learn, packaging, numba, importlib-resources, contourpy, stdlib-list, pynndescent, patsy, pandas, natsort, matplotlib, exceptiongroup, array-api-compat, umap-learn, statsmodels, session-info, seaborn, networkx, legacy-api-wrap, get-annotations, anndata, scanpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.37.0
#     Uninstalling llvmlite-0.37.0:
#       Successfully uninstalled llvmlite-0.37.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.54.1
#     Uninstalling numba-0.54.1:
#       Successfully uninstalled numba-0.54.1
#   Attempting uninstall: patsy
#     Found existing installation: patsy 0.5.2
#     Uninstalling patsy-0.5.2:
#       Successfully uninstalled patsy-0.5.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Uninstalling pandas-1.3.4:
#       Successfully uninstalled pandas-1.3.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Uninstalling matplotlib-3.4.3:
#       Successfully uninstalled matplotlib-3.4.3
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.6.3
#     Uninstalling networkx-2.6.3:
#       Successfully uninstalled networkx-2.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# Successfully installed anndata-0.10.9 array-api-compat-1.11.2 contourpy-1.3.0 exceptiongroup-1.3.0 get-annotations-0.1.2 importlib-resources-6.5.2 joblib-1.5.1 legacy-api-wrap-1.4.1 llvmlite-0.43.0 matplotlib-3.9.4 natsort-8.4.0 networkx-3.2.1 numba-0.60.0 numpy-2.0.2 packaging-25.0 pandas-2.3.1 patsy-1.0.1 pynndescent-0.5.13 scanpy-1.10.3 scikit-learn-1.6.1 scipy-1.13.1 seaborn-0.13.2 session-info-1.0.1 statsmodels-0.14.5 stdlib-list-0.11.1 threadpoolctl-3.6.0 typing-extensions-4.14.1 tzdata-2025.2 umap-learn-0.5.9.post2
# Collecting igraph
#   Downloading igraph-0.11.9-cp39-abi3-macosx_10_9_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 9.5 MB/s eta 0:00:01
# Collecting texttable>=1.6.2
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-0.11.9 texttable-1.7.0
# Collecting leidenalg
#   Downloading leidenalg-0.10.2-cp38-abi3-macosx_10_9_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 7.1 MB/s eta 0:00:01
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from leidenalg) (0.11.9)
# Requirement already satisfied: texttable>=1.6.2 in /Users/iwata/opt/anaconda3/lib/python3.9/site-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.7.0)
# Installing collected packages: leidenalg
# Successfully installed leidenalg-0.10.2

# %% [markdown]
# 関連ライブラリを読み込む

# %%
import scanpy as sc
import pandas as pd

# %% [markdown]
# ## 📥 1. データ読み込み（PBMC3k）

# %%
adata = sc.datasets.pbmc3k()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'

# %% [markdown]
# 2700細胞 x 32738遺伝子のAnnDataが作成されました。

# %% [markdown]
# 各細胞の全リードに対して占める割合が最も高い遺伝子を表示します。

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )

# %% [markdown]
# ここからどんどんフィルタリングします。

# %% [markdown]
# ## 🔬 2. 品質管理（QC）と前処理
# 発現遺伝子数が200未満の細胞、発現細胞数が3未満の遺伝子をフィルタします。

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 13714
#     obs: 'n_genes'
#     var: 'gene_ids', 'n_cells'

# %% [markdown]
# 発現細胞数が3未満の19,024遺伝子がフィルタされ、2700細胞 x 13714遺伝子のAnnDataになりました。

# %% [markdown]
# 次に、品質評価に重要なミトコンドリア遺伝子の発現量を計測します。 ミトコンドリアの発現割合が高い細胞は死細胞とみなされます。 (Lun, McCarthy & Marioni, 2017)

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %% [markdown]
# 異常な細胞（ミトコンドリア高い、遺伝子数多すぎ）を除去）
# ミトコンドリア由来の遺伝子が多すぎる細胞(5%以上)、またはtotal countsの値が多すぎる細胞(2500以上)を削除します。

# %%
adata = adata[adata.obs.n_genes_by_counts < 2500, :]
adata = adata[adata.obs.pct_counts_mt < 5, :]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 2638 × 13714
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# 2638細胞 x 13714遺伝子のAnnDataになりました。

# %% [markdown]
# ## 🧪 3. 正規化とスケーリング
# 各細胞の総カウントをそろえて10000に正規化

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %% [markdown]
# 対数変換（log1p = log(x+1)）

# %%
sc.pp.log1p(adata)

# %% [markdown]
# 変動の大きい遺伝子（高変動遺伝子）の選択

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
adata = adata[:, adata.var.highly_variable]

# %% [markdown]
# スケーリング（平均0・分散1に標準化）

# %%
sc.pp.scale(adata, max_value=10)
# Out:
# /usr/local/lib/python3.11/dist-packages/scanpy/preprocessing/_scale.py:309: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /usr/lib/python3.11/functools.py:909: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)

# %% [markdown]
# ## 🌐 4. 次元削減とクラスタリング
# 主成分分析（PCA）

# %%
sc.tl.pca(adata)

# %% [markdown]
# 近傍グラフの計算を行います。これは細胞間の距離（類似性や関連性）を数値化し、細胞間の関係をグラフ構造で表現することを目的としています。

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)

# %% [markdown]
# UMAPによる2次元可視化

# %%
sc.tl.umap(adata)

# %% [markdown]
# 近傍グラフのクラスタリングを行います。

# %%
sc.tl.leiden(adata, resolution=0.5)  # louvainでも可
# Out:
# /tmp/ipython-input-17-3820399377.py:1: FutureWarning: In the future, the default backend for leiden will be igraph instead of leidenalg.
#
#  To achieve the future defaults please pass: flavor="igraph" and n_iterations=2.  directed must also be False to work with igraph's implementation.
#   sc.tl.leiden(adata, resolution=0.5)  # louvainでも可

# %% [markdown]
# クラスタごとに色を付けてUMAPを表示

# %%
sc.pl.umap(adata, color='leiden', title='Leiden Clustering')

# %% [markdown]
# ## 🧬 5. クラスタごとのマーカー遺伝子抽出

# %%
sc.tl.rank_genes_groups(adata, groupby='leiden', method='wilcoxon')
# Out:
# /usr/local/lib/python3.11/dist-packages/scanpy/tools/_rank_genes_groups.py:482: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.11/dist-packages/scanpy/tools/_rank_genes_groups.py:482: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.11/dist-packages/scanpy/tools/_rank_genes_groups.py:482: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.11/dist-packages/scanpy/tools/_rank_genes_groups.py:482: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.11/dist-packages/scanpy/tools/_rank_genes_groups.py:482: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# /usr/local/lib/python3.11/dist-packages/scanpy/tools/_rank_genes_groups.py:482: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %% [markdown]
# 各クラスタのマーカー遺伝子（上位20）を可視化

# %%
sc.pl.rank_genes_groups(adata, n_genes=20, sharey=False)

# %% [markdown]
# ## 📥 6. PanglaoDBのマーカー遺伝子を読み込み

# %%
import pandas as pd
panglao = pd.read_csv("https://github.com/iwata97/bioinfo/raw/refs/heads/main/PanglaoDB_markers_27_Mar_2020.tsv", sep="\t")

# %% [markdown]
# ヒトのマーカーのみ抽出

# %%
panglao = panglao[panglao["species"] == "Hs"]
panglao.head()
# Out:
#    species official gene symbol     cell type             nicknames  \
# 22      Hs                CTRB2  Acinar cells                   NaN
# 26      Hs                REG1A  Acinar cells        PSPS|PSPS1|REG
# 31      Hs             SERPINA3  Acinar cells                  AACT
# 33      Hs                REG1B  Acinar cells  PSPS2|REGH|REGI-BETA
# 37      Hs             C15ORF48  Acinar cells       NMES1|MIR147BHG
#
#     ubiquitousness index                  product description  \
# 22                 0.001                  chymotrypsinogen B2
# 26                 0.005   regenerating family member 1 alpha
# 31                 0.000             serpin family A member 3
# 33                 0.002    regenerating family member 1 beta
# 37                 0.018  chromosome 15 open reading frame 48
#
#               gene type  canonical marker germ layer     organ  \
# 22  protein-coding gene               1.0   Endoderm  Pancreas
# 26  protein-coding gene               1.0   Endoderm  Pancreas
# 31  protein-coding gene               1.0   Endoderm  Pancreas
# 33  protein-coding gene               1.0   Endoderm  Pancreas
# 37  protein-coding gene               1.0   Endoderm  Pancreas
#
#     sensitivity_human  sensitivity_mouse  specificity_human  specificity_mouse
# 22           0.916667                0.0           0.001258                0.0
# 26           1.000000                0.0           0.027359                0.0
# 31           0.000000                0.0           0.000314                0.0
# 33           0.916667                0.0           0.011006                0.0
# 37           1.000000                0.0           0.109119                0.0

# %% [markdown]
# ## 🔍 7. クラスタごとに細胞型を推定（PanglaoDBと照合）

# %%
cluster_to_celltype = {}

for cluster in adata.obs['leiden'].cat.categories:
    # 各クラスタの上位20マーカー遺伝子を取得
    genes = adata.uns['rank_genes_groups']['names'][cluster][:20]
    # PanglaoDBで一致する細胞型を検索
    matched = panglao[panglao['official gene symbol'].isin(genes)]
    if not matched.empty:
        predicted_type = matched['cell type'].value_counts().idxmax()
    else:
        predicted_type = 'Unknown'
    cluster_to_celltype[cluster] = predicted_type

# %% [markdown]
# 結果表示

# %%
cluster_to_celltype
# Out:
# {'0': 'Decidual cells',
#  '1': 'Monocytes',
#  '2': 'NK cells',
#  '3': 'Dendritic cells',
#  '4': 'Dendritic cells',
#  '5': 'Unknown'}

# %% [markdown]
# ## 🏷 8. 細胞型ラベルを各細胞に割り当てる

# %%
adata.obs['celltype'] = adata.obs['leiden'].map(cluster_to_celltype)

# %% [markdown]
# ## 🎨 9. 細胞型ラベルでUMAPを描画

# %%
sc.pl.umap(adata, color='celltype', legend_loc='on data', title='Predicted Cell Types from PanglaoDB')

# %% [markdown]
# 参考ページ
# https://singlecellanalysistutorial.readthedocs.io/en/latest/notebooks/Scanpy_PBMC.html?utm_source=chatgpt.com
# https://qiita.com/nikera/items/45cc4d6491182d1e0aab
